# %%
import pandas as pd

# %%
df = pd.read_csv('/content/datos_seguros.csv', sep=';') # sep=';'
df.head()
# Out:
#    MES_T0  VENTA_SEGURO  NUM_TC_TOTAL_T2  SALDO_BCO_T2  LINEA_BCO_T2  \
# 0  201506             0              3.0           0.0        2300.0
# 1  201506             0              2.0        3215.0        3500.0
# 2  201506             0              1.0        3169.0        5000.0
# 3  201506             1              1.0        6495.0        8450.0
# 4  201506             0              NaN           NaN           NaN
#
#    USO_LINEA_BCO_T2  Nro_CTa_Ahorro_Bco_T1  Ahorro_Sldo_Bco_T1  monto_ope_t2  \
# 0          0.000000                    0.0                 0.0         15.00
# 1          0.918571                    0.0                 0.0        548.98
# 2          0.633800                    0.0                 0.0          0.00
# 3          0.768639                    2.0               505.0       2137.94
# 4               NaN                    0.0                 0.0         12.37
#
#    PROM_ANUAL_MTO_OPERA  MAX_MTO_OPERA_Anual  Ratio_HospvsMtoTotal_t2 SEXO  \
# ...

# %%
num_filas, num_columnas = df.shape
print("DataFrame cargado:")
print(df)

# %%
df.info()

# %%
primeras_10_filas = df.head(10)
print("Primeras 10 filas:")
print(primeras_10_filas)

# %%
# Obtener las últimas 10 filas del DataFrame
ultimas_10_filas = df.tail(10)
print("\nÚltimas 10 filas:")
print(ultimas_10_filas)

# %%
# Extraer las primeras 1000 filas del DataFrame
primeras_1000_filas = df.head(1000)

# Imprimir las dimensiones del nuevo contenedor
num_filas_nuevo_contenedor, num_columnas_nuevo_contenedor = primeras_1000_filas.shape
print(f"Dimensiones del nuevo contenedor:")
print(f"Número de filas: {num_filas_nuevo_contenedor}")
print(f"Número de columnas: {num_columnas_nuevo_contenedor}")
primeras_1000_filas
# Out:
# Dimensiones del nuevo contenedor:
# Número de filas: 1000
# Número de columnas: 17
#      MES_T0  VENTA_SEGURO  NUM_TC_TOTAL_T2  SALDO_BCO_T2  LINEA_BCO_T2  \
# 0    201506             0              3.0           0.0        2300.0
# 1    201506             0              2.0        3215.0        3500.0
# 2    201506             0              1.0        3169.0        5000.0
# 3    201506             1              1.0        6495.0        8450.0
# 4    201506             0              NaN           NaN           NaN
# ..      ...           ...              ...           ...           ...
# 995  201506             0              1.0        4357.0        4600.0
# 996  201506             0              NaN           NaN           NaN
# 997  201506             0              NaN           NaN           NaN
# 998  201506             0              1.0           0.0           0.0
# 999  201506             0              4.0           0.0           0.0
#
# ...
